# %%
# @title SPADE Fine-Tuning (Colab Demo)
# @markdown Run this notebook to train and visualize SPADE fine-tuning on Colab GPU.

# !nvidia-smi

# Clone your repo
# !git clone https://github.com/patilgayatri22/Segmentation_Style_GAN.git
# %cd /content/Segmentation_Style_GAN/SPADE_Pix2Pix

# Install dependencies
# !pip install -r requirements.txt

# Train (shorter epochs for demo)
# !python src/train_spade.py

# %%
# Visualize sample outputs
from PIL import Image
from IPython.display import display
import glob

for img_path in sorted(glob.glob("outputs_spade_finetune/samples/*.jpg"))[-3:]:
    display(Image.open(img_path))
